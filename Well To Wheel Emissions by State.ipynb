# %%
import pandas as pd
import matplotlib.pyplot as plt
import random as random

W2W = pd.read_excel("data/fotw#950_web.xlsx")
wheel_csv = W2W.to_csv("data/fotw#950_web.csv", index="state", header=True)
well_to_whell = pd.read_csv('data/fotw#950_web.csv')
almost = well_to_whell.dropna()
almost
almost_there = almost.drop(['Unnamed: 0'], axis=1)
almost_there.columns
#almost_there.drop(['5'])
# Out:
# Index(['U.S. Department of Energy, Vehicle Technology Office', 'Unnamed: 1'], dtype='object')

# %%
new = almost_there.set_index('U.S. Department of Energy, Vehicle Technology Office')
almost_clean = new.drop(['State'])
almost_clean.columns
so_close = almost_clean.rename(columns={'Unnamed: 1': "Pounds of CO2 Equivalent"}) 
so_close.index
# Out:
# Index(['Vermont', 'Washington', 'Idaho', 'Maine', 'Oregon', 'New Hampshire',
#        'South Dakota', 'New York', 'Connecticut', 'New Jersey', 'California',
#        'South Carolina', 'Massachusetts', 'Virginia', 'Illinois',
#        'Rhode Island', 'Mississippi', 'Alaska', 'Pennsylvania', 'Maryland',
#        'North Carolina', 'District of Columbia', 'Tennessee', 'Louisiana',
#        'Georgia', 'Nevada', 'Alabama', 'Florida', 'Arizona', 'Arkansas',
#        'Texas', 'Minnesota', 'Oklahoma', 'Iowa', 'Kansas', 'Michigan',
#        'Delaware', 'Montana', 'Nebraska', 'Wisconsin', 'Hawaii', 'Colorado',
#        'Ohio', 'New Mexico', 'North Dakota', 'Missouri', 'Utah', 'Indiana',
#        'Wyoming', 'Kentucky', 'West Virginia', 'EV National Average',
#        'Gasoline Vehicle Average'],
#       dtype='object', name='U.S. Department of Energy, Vehicle Technology Office')

# %%
new = almost_there.set_index('U.S. Department of Energy, Vehicle Technology Office')
almost_clean = new.drop(['State'])
almost_clean.columns
so_close = almost_clean.rename(columns={'Unnamed: 1': "Pounds of CO2 Equivalent"}) 
#so_close.rename(={'U.S. Department of Energy, Vehicle Technology Office':"States"})
so_close. index
state =['Vermont', 'Washington', 'Idaho', 'Maine', 'Oregon', 'New Hampshire',
       'South Dakota', 'New York', 'Connecticut', 'New Jersey', 'California',
       'South Carolina', 'Massachusetts', 'Virginia', 'Illinois',
       'Rhode Island', 'Mississippi', 'Alaska', 'Pennsylvania', 'Maryland',
       'North Carolina', 'District of Columbia', 'Tennessee', 'Louisiana',
       'Georgia', 'Nevada', 'Alabama', 'Florida', 'Arizona', 'Arkansas',
       'Texas', 'Minnesota', 'Oklahoma', 'Iowa', 'Kansas', 'Michigan',
       'Delaware', 'Montana', 'Nebraska', 'Wisconsin', 'Hawaii', 'Colorado',
       'Ohio', 'New Mexico', 'North Dakota', 'Missouri', 'Utah', 'Indiana',
       'Wyoming', 'Kentucky', 'West Virginia', 'EV National Average',
       'Gasoline Vehicle Average']

CO2 =[ 0,987,1179,1559,1644,1886,1941,2112,2336,2529,2706,3090,3803,3931,4003,4122,4140,4182,4278,4378,4395,4540,4563,4588
,4643,4689,4815,4830,4845,5059,5086,5142,5271,5440,5444,5520,5654,5670,6108,6443,6696,6936,6958,7446,7470,8328,8362
,8682,8823,8965,9451,4815,11435]

data = {'State': ['Vermont', 'Washington', 'Idaho', 'Maine', 'Oregon', 'New Hampshire',
       'South Dakota', 'New York', 'Connecticut', 'New Jersey', 'California',
       'South Carolina', 'Massachusetts', 'Virginia', 'Illinois',
       'Rhode Island', 'Mississippi', 'Alaska', 'Pennsylvania', 'Maryland',
       'North Carolina', 'District of Columbia', 'Tennessee', 'Louisiana',
       'Georgia', 'Nevada', 'Alabama', 'Florida', 'Arizona', 'Arkansas',
       'Texas', 'Minnesota', 'Oklahoma', 'Iowa', 'Kansas', 'Michigan',
       'Delaware', 'Montana', 'Nebraska', 'Wisconsin', 'Hawaii', 'Colorado',
       'Ohio', 'New Mexico', 'North Dakota', 'Missouri', 'Utah', 'Indiana',
       'Wyoming', 'Kentucky', 'West Virginia', 'EV National Average',
       'Gasoline Vehicle Average'],
       'Pounds of CO2 Equivalent':[ 0,987,1179,1559,1644,1886,1941,2112,2336,2529,2706,3090,3803,3931,4003,4122,4140,4182,4278,4378,4395,4540,4563,4588
        ,4643,4689,4815,4830,4845,5059,5086,5142,5271,5440,5444,5520,5654,5670,6108,6443,6696,6936,6958,7446,7470,8328,8362
        ,8682,8823,8965,9451,4815,11435]}


clean = pd.DataFrame(data)
clean
# Out:
#                        State  Pounds of CO2 Equivalent
# 0                    Vermont                         0
# 1                 Washington                       987
# 2                      Idaho                      1179
# 3                      Maine                      1559
# 4                     Oregon                      1644
# 5              New Hampshire                      1886
# 6               South Dakota                      1941
# 7                   New York                      2112
# 8                Connecticut                      2336
# 9                 New Jersey                      2529
# 10                California                      2706
# 11            South Carolina                      3090
# 12             Massachusetts                      3803
# 13                  Virginia                      3931
# 14                  Illinois                      4003
# 15              Rhode Island                      4122
# ...

# %%
plt.figure(figsize=(12,6))
plt.grid(True, color="black")
plt.bar(state,CO2, align='center', width=1.5, color='chartreuse', edgecolor= "grey")
plt.title('Emmisions From All Electrical Vehicles By State ')
plt.xlabel('State')
plt.ylabel('CO2 Emissions in lbs')
plt.xticks(rotation = 85)
plt.savefig('output/Emmisions From All Electrical Vehicles By State.jpeg')


plt.show()

# %%
Ev_Gas =clean.iloc[51:53]
Avgs = ['EV National Averages','Gasoline Vehicle Average']
Totals= [4815,11435]
colors= ['forestgreen','firebrick']
plt.figure(figsize=(5,6))
plt.grid(True, color="black")
plt.bar(Avgs,Totals, align='center', width=.8, color= colors, edgecolor= colors)
plt.title('Electrical vs Gasoline National Emmisions')
plt.xlabel('Fuel Type')
plt.ylabel('CO2 Emissions in lbs')
plt.savefig('output/Electrical vs Gasoline National Emmisions.jpeg')
plt.show()

# %%
#https://afdc.energy.gov/vehicles/electric_emissions.html  
#data taken from widget in link 
electricity_sources = {'Alabama (AL)':       {'Natural Gas':44.37,'Nuclear':29.12,'Coal':13.17,'Solar':6.16, 'Hydro':5.44, 'Wind':1.47, 'Biomass':.24,  'Oil':.04},
                       'Alaska (AK)':        {'Natural Gas':41.03,'Nuclear':0,    'Coal':13.67,'Solar':0,    'Hydro':27.68,'Wind':2.17, 'Biomass':.64,  'Oil':14.9},
                       'Arizona (AZ)':       {'Natural Gas':44.37,'Nuclear':29.12,'Coal':13.17,'Solar':6.16, 'Hydro':5.44, 'Wind':1.47, 'Biomass':.24,  'Oil':.04},
                       'Arkansas (AR)':      {'Natural Gas':32.11,'Nuclear':22.51,'Coal':35.56,'Solar':.77,  'Hydro':7.31, 'Wind':0,    'Biomass':1.65, 'Oil':.08},
                       'Texas (TX)':         {'Natural Gas':48.82,'Nuclear':8.36, 'Coal':18.45,'Solar':2.94, 'Hydro':.23,  'Wind':20.79,'Biomass':.29,  'Oil':.04},
                       'Florida (FL)':       {'Natural Gas':73.9, 'Nuclear':11.48,'Coal':7.52, 'Solar':3.70, 'Hydro':.09,  'Wind':0,    'Biomass':1.72, 'Oil':.48},
                       'Kentucky (KY)':      {'Natural Gas':21.04,'Nuclear':0,    'Coal':70.67,'Solar':0.06, 'Hydro':7.47, 'Wind':0,    'Biomass':.51,  'Oil':.15},
                       'South Carolina (SC)':{'Natural Gas':23.29,'Nuclear':53.81,'Coal':15.20,'Solar':2.28, 'Hydro':2.95, 'Wind':0,    'Biomass':2.31, 'Oil':.11},
                       'Vermont (VT)' :      {'Natural Gas':.1   ,'Nuclear':0,    'Coal':0,    'Solar':8.78, 'Hydro':50.13,'Wind':15.77,'Biomass':25.11,'Oil':0},
                       'Washington (WA)':    {'Natural Gas':14.43,'Nuclear':7.82, 'Coal':2.88, 'Solar':.05,  'Hydro':64.70,'Wind':8.73, 'Biomass':1.32, 'Oil':.02},
                       'Wisconsin (WI)':     {'Natural Gas':33.92,'Nuclear':15.23, 'Coal':41.91, 'Solar':.6, 'Hydro':3.82, 'Wind':2.47, 'Biomass':1.72, 'Oil':.29}}

# %%
AnnualEmissionsperVehicle={'Alabama (AL)':   {'All Electric':3562, "Plug-in Hybrid":5546,'Hybrid':6258,'Gasoline':11435},
                           'Alaska (AK)':    {'All Electric':4335, "Plug-in Hybrid":6034,'Hybrid':6258,'Gasoline':11435},
                           'Arizona (AZ)':   {'All Electric':3313, "Plug-in Hybrid":5389,'Hybrid':6258,'Gasoline':11435},
                           'Arkansas (AR)':  {'All Electric':4962, "Plug-in Hybrid":6429,'Hybrid':6258,'Gasoline':11435},
                           'Texas (TX)' :    {'All Electric':4035, "Plug-in Hybrid":5844,'Hybrid':6258,'Gasoline':11435},
                           'Florida (FL)':   {'All Electric':4131, "Plug-in Hybrid":5905,'Hybrid':6258,'Gasoline':11435},
                           'Kentucky (KY)':  {'All Electric':7919, "Plug-in Hybrid":8294,'Hybrid':6258,'Gasoline':11435},
                           'South Carolina (SC)':{'All Electric':2561, "Plug-in Hybrid":4915,'Hybrid':6258,'Gasoline':11435},
                           'Vermont (VT)' :  {'All Electric':0,    "Plug-in Hybrid":3302,'Hybrid':6258,'Gasoline':11435},
                           'Washington (WA)':{'All Electric':940,  "Plug-in Hybrid":3892,'Hybrid':6258,'Gasoline':11435},
                           'Wisconsin (WI)' :{'All Electric':5685,  "Plug-in Hybrid":6885,'Hybrid':6258,'Gasoline':11435}}

# %%
Electricity_sources_df=pd.DataFrame(electricity_sources)
Electricity_sources_df
# Out:
#              Alabama (AL)  Alaska (AK)  Arizona (AZ)  Arkansas (AR)  \
# Natural Gas         44.37        41.03         44.37          32.11
# Nuclear             29.12         0.00         29.12          22.51
# Coal                13.17        13.67         13.17          35.56
# Solar                6.16         0.00          6.16           0.77
# Hydro                5.44        27.68          5.44           7.31
# Wind                 1.47         2.17          1.47           0.00
# Biomass              0.24         0.64          0.24           1.65
# Oil                  0.04        14.90          0.04           0.08
#
#              Texas (TX)  Florida (FL)  Kentucky (KY)  South Carolina (SC)  \
# Natural Gas       48.82         73.90          21.04                23.29
# Nuclear            8.36         11.48           0.00                53.81
# Coal              18.45          7.52          70.67                15.20
# ...

# %%
EmissonsPerVehicle=pd.DataFrame(AnnualEmissionsperVehicle)
EmissonsPerVehicle.T
# Out:
#                      All Electric  Plug-in Hybrid  Hybrid  Gasoline
# Alabama (AL)                 3562            5546    6258     11435
# Alaska (AK)                  4335            6034    6258     11435
# Arizona (AZ)                 3313            5389    6258     11435
# Arkansas (AR)                4962            6429    6258     11435
# Texas (TX)                   4035            5844    6258     11435
# Florida (FL)                 4131            5905    6258     11435
# Kentucky (KY)                7919            8294    6258     11435
# South Carolina (SC)          2561            4915    6258     11435
# Vermont (VT)                    0            3302    6258     11435
# Washington (WA)               940            3892    6258     11435
# Wisconsin (WI)               5685            6885    6258     11435
